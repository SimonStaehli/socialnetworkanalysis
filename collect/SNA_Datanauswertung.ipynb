# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
# %pwd
# Out:
# 'C:\\Users\\thoma\\Documents\\FHNW\\3 Soziale Netzwerke'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'copp.txt',
#  'creds.yaml',
#  'Gephi Bilder',
#  'RT_vegan_2021-03-04.csv',
#  'SAN Unterlagen',
#  'schoolday.gexf',
#  'SNA Datanauswertung.ipynb',
#  'SNAScript.pdf',
#  'socialnetworkanalysis',
#  'test.yaml',
#  'tweet.txt',
#  'Twitter Test.ipynb',
#  'Twitter.docx',
#  'twitter_api-Copy2.ipynb',
#  'twitter_api.ipynb',
#  'TW_vegan_2021-03-04.csv',
#  'Untitled.ipynb']

# %%
df=pd.read_csv("TW_vegan_2021-03-04.csv")
df.head(2)
# Out:
#    Unnamed: 0             tweet_id                   creation_date  \
# 0           0  1367200018428551179  Wed Mar 03 19:47:40 +0000 2021
# 1           1  1366871944738537472  Tue Mar 02 22:04:01 +0000 2021
#
#                                            full_text mentions  \
# 0  Had a lovely vegan lunch.  Then proceeded dire...       []
# 1  Black-owned restaurant Bam’s Vegan opens in Ir...       []
#
#                                 entities_hashtags            user_name  \
# 0                                              []   Angelica Love Ross
# 1  [{'text': 'LocalIrving', 'indices': [51, 63]}]  Dallas Morning News
#
#   user_screen_name   user_id       location  \
# 0     angelicaross  18634831    Atlanta, GA
# 1       dallasnews  15679641  Dallas, Texas
#
#                                          description  protected  \
# 0  ALL BLACK LIVES MATTER @TransTechSocial @MissR...      False
# 1  The official Dallas Morning News Twitter accou...      False
#
# ...

# %%
df2=pd.read_csv("TW_vegan_2021-03-11.csv")
df2.head(2)
# Out:
#    Unnamed: 0             tweet_id                   creation_date  \
# 0           0  1369690557006700545  Wed Mar 10 16:44:11 +0000 2021
# 1           1  1369709136661872640  Wed Mar 10 17:58:00 +0000 2021
#
#                                            full_text  \
# 0  hopping on an ig live with momma of the people...
# 1  You lot have been asking me about recipes for ...
#
#                            mentions entities_hashtags               user_name  \
# 0  ['billieeilish', 'gooddyeyoung']                []  hayley from Paramore 🥀
# 1                                []                []                 Big Zuu
#
#   user_screen_name   user_id       location  \
# 0   yelyahwilliams  40981798  Nashville, TN
# 1        ItsBigZuu  92539495    West London
#
#                                     description  protected  followers_count  \
# 0  tiny hot topic bitch @paramore @goodDYEyoung      False          5091727
# ...

# %%
chart_1 = df[['user_name','retweet_count','followers_count']]

chart_1.sort_values(by=['retweet_count'], 
    ascending=False).plot(x="user_name", 
    y =["retweet_count",], kind = "bar",
    title = "03042021"   ,                   
    figsize = (15,3))
# Out:
# <AxesSubplot:title={'center':'03042021'}, xlabel='user_name'>

# %%
chart_11 = df2[['user_name','retweet_count','followers_count']]

chart_11.sort_values(by=['retweet_count'], 
    ascending=False).plot(x="user_name", 
    y =["retweet_count",], kind = "bar",
    title = "03112021",
    figsize = (15,3))
# Out:
# <AxesSubplot:title={'center':'03112021'}, xlabel='user_name'>

# %%
followers = df[['user_name','retweet_count','followers_count']]
followers.sort_values(by=['followers_count'],ascending=False)
# Out:
#               user_name  retweet_count  followers_count
# 22           KATY PERRY            268        109522655
# 20         jimmy fallon            338         51878237
# 27   The New York Times             93         49543493
# 21        Lili Reinhart            739          3386115
# 7                 Tasty             50          1423269
# 10                Tasty             45          1423269
# 14                 PETA             45          1082080
# 29                 PETA            110          1082080
# 13                  AJC             45          1060185
# 24        Padma Lakshmi             85           780323
# 12         Skai Jackson             35           730072
# 1   Dallas Morning News            138           707347
# 17             CupcakKe            658           604214
# 23              Karlous            254           590187
# 11         elfcosmetics             96           492219
# 9       Michael Harriot             27           405264
# ...

# %%
followers = df[['user_name','retweet_count','followers_count']].plot(x = "followers_count", y = "retweet_count", kind = "scatter", figsize = (16, 8))

# %%
# sns.scatterplot(data=followers, x = "followers_count", y = "retweet_count")

# %%
df=pd.read_csv("RT_vegan_2021-03-04.csv")
chart_2 = df.sort_values(by=['followers_count'],ascending=False)
chart_2.tail()
# Out:
#      Unnamed: 0             tweet_id                   creation_date  \
# 95           95  1367129921731059721  Wed Mar 03 15:09:08 +0000 2021
# 30           30  1367360857651355648  Thu Mar 04 06:26:47 +0000 2021
# 96           96  1367107435668770820  Wed Mar 03 13:39:46 +0000 2021
# 33           33  1367341183538716672  Thu Mar 04 05:08:36 +0000 2021
# 129         129  1367021749003423745  Wed Mar 03 07:59:17 +0000 2021
#
#                                              full_text  \
# 95   RT @skaijackson: Y’all, I got a vegan cook boo...
# 30   RT @tasty: Easy Vegan Comfort Food https://t.c...
# 96   RT @skaijackson: Y’all, I got a vegan cook boo...
# 33   RT @tasty: Easy Vegan Comfort Food https://t.c...
# 129  RT @peta: Fish are animals who feel pain, just...
#
#                      mentions                         entities_hashtags  \
# 95            ['skaijackson']                                        []
# ...

# %%
df0311=pd.read_csv("RT_vegan_2021-03-11.csv")
chart_21 = df.sort_values(by=['followers_count'],ascending=False)
chart_21.tail()
# Out:
#     Unnamed: 0             tweet_id                   creation_date  \
# 16          16  1366789932568748035  Tue Mar 02 16:38:08 +0000 2021
# 19          19  1366771732078600198  Tue Mar 02 15:25:48 +0000 2021
# 2            2  1367409141413597192  Thu Mar 04 09:38:39 +0000 2021
# 4            4  1366854255022202881  Tue Mar 02 20:53:43 +0000 2021
# 26          26  1365579214896865280  Sat Feb 27 08:27:10 +0000 2021
#
#                                             full_text  \
# 16  The owners of @bd_cheesesteaks and @sluttyvega...
# 19  Some say healthy food is too expensive, and I ...
# 2   Delighted to meet Sh. Sahil Agnihotri, Co-foun...
# 4   "i HatE IT whEn VEGAns FOrCE ThEir lIfestyle o...
# 26            Vegan Indian food is seriously top tier
#
#                                  mentions  \
# 16  ['BD_Cheesesteaks', 'SluttyVeganATL']
# 19                                     []
# 2          ['MistayaSweets', 'sahil0204']
# 4                                      []
# ...

# %%
a = chart_2.sort_values(by=['retweet_count'], ascending=False)
a
# Out:
#      Unnamed: 0             tweet_id                   creation_date  \
# 21           21  1367439983980777478  Thu Mar 04 11:41:12 +0000 2021
# 32           32  1367344647220031490  Thu Mar 04 05:22:22 +0000 2021
# 29           29  1367363236580921344  Thu Mar 04 06:36:14 +0000 2021
# 23           23  1367435502501126145  Thu Mar 04 11:23:24 +0000 2021
# 22           22  1367437662186074115  Thu Mar 04 11:31:59 +0000 2021
# ..          ...                  ...                             ...
# 171         171  1367002138149146634  Wed Mar 03 06:41:22 +0000 2021
# 177         177  1366865743946477569  Tue Mar 02 21:39:23 +0000 2021
# 183         183  1366786561589788673  Tue Mar 02 16:24:44 +0000 2021
# 167         167  1367126056537235462  Wed Mar 03 14:53:46 +0000 2021
# 179         179  1366862078171115529  Tue Mar 02 21:24:49 +0000 2021
#
#                                              full_text           mentions  \
# ...

# %%
b = chart_21.sort_values(by=['retweet_count'], ascending=False)
b
# Out:
#     Unnamed: 0             tweet_id                   creation_date  \
# 21          21  1366449193741656067  Mon Mar 01 18:04:09 +0000 2021
# 17          17  1366206300854636546  Mon Mar 01 01:58:59 +0000 2021
# 18          18  1365321221366194176  Fri Feb 26 15:22:00 +0000 2021
# 20          20  1364816859392925698  Thu Feb 25 05:57:51 +0000 2021
# 0            0  1367200018428551179  Wed Mar 03 19:47:40 +0000 2021
# 22          22  1366257175945875461  Mon Mar 01 05:21:09 +0000 2021
# 23          23  1364984413138911243  Thu Feb 25 17:03:38 +0000 2021
# 26          26  1365579214896865280  Sat Feb 27 08:27:10 +0000 2021
# 25          25  1365975536774823938  Sun Feb 28 10:42:01 +0000 2021
# 1            1  1366871944738537472  Tue Mar 02 22:04:01 +0000 2021
# 4            4  1366854255022202881  Tue Mar 02 20:53:43 +0000 2021
# 15          15  1366770843670478858  Tue Mar 02 15:22:17 +0000 2021
# 28          28  1365773453291360277  Sat Feb 27 21:19:00 +0000 2021
# ...

# %%
plt.figure(figsize=(15,8))
ax = sns.barplot(x="user_id", y="retweet_count", data=a)

# %%
a.plot(x="user_id", 
    y =["retweet_count",], kind = "bar",
    figsize = (15,10))
# Out:
# <AxesSubplot:xlabel='user_id'>

# %%
b.plot(x="user_id", 
    y =["retweet_count",], kind = "bar",
    figsize = (15,10))
# Out:
# <AxesSubplot:xlabel='user_id'>
